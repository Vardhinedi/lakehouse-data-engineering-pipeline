# %%
snowflakeOptions = {
    "host": "OEFRXSF-RS36003.snowflakecomputing.com",
    "sfUser": "CHETAN116",
    "sfPassword": "Vcp5869ms2002@",
    "sfDatabase": "LAKEHOUSE_DB",
    "sfSchema": "ANALYTICS",
    "sfWarehouse": "LAKEHOUSE_WH",
    "sfRole": "ACCOUNTADMIN"
}

print("Snowflake Config Loaded!")
# Out:
# Snowflake Config Loaded!

# %%
top_customers_df = spark.read.format("delta").load(
    "/Volumes/workspace/default/lakehouse_raw_data/gold/top_customers"
)

daily_revenue_df = spark.read.format("delta").load(
    "/Volumes/workspace/default/lakehouse_raw_data/gold/daily_revenue"
)

revenue_by_country_df = spark.read.format("delta").load(
    "/Volumes/workspace/default/lakehouse_raw_data/gold/revenue_by_country"
)

print("Gold Layer Loaded Successfully!")
# Out:
# Gold Layer Loaded Successfully!

# %%
display(top_customers_df.limit(10))

display(daily_revenue_df.limit(10))

display(revenue_by_country_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>total_spent</th></tr></thead><tbody><tr><td>Jessica Smith</td><td>154490.46</td></tr><tr><td>David White</td><td>112474.3</td></tr><tr><td>Michael Smith</td><td>112452.81</td></tr><tr><td>Ashley Jackson</td><td>103501.46</td></tr><tr><td>Christopher Miller</td><td>102951.86</td></tr><tr><td>Ashley Richardson</td><td>100192.71</td></tr><tr><td>Julie Lee</td><td>96616.92</td></tr><tr><td>Jordan Jones</td><td>92498.89</td></tr><tr><td>Christopher Davis</td><td>92061.75</td></tr><tr><td>Michael Davis</td><td>89491.83</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
# ...

# %%
print("Testing Snowflake Connection...")

test_df = spark.createDataFrame(
    [(1, "test")],
    ["id", "name"]
)

test_df.write \
    .format("snowflake") \
    .options(**snowflakeOptions) \
    .option("dbtable", "CONNECTION_TEST") \
    .mode("overwrite") \
    .save()

print("Snowflake Connection Successful!")
# Out:
# Testing Snowflake Connection...
# Snowflake Connection Successful!

# %%
top_customers_df.write \
    .format("snowflake") \
    .options(**snowflakeOptions) \
    .option("dbtable", "TOP_CUSTOMERS") \
    .mode("overwrite") \
    .save()

print("TOP_CUSTOMERS Exported!")
# Out:
# TOP_CUSTOMERS Exported!

# %%
daily_revenue_df.write \
    .format("snowflake") \
    .options(**snowflakeOptions) \
    .option("dbtable", "DAILY_REVENUE") \
    .mode("overwrite") \
    .save()

print("DAILY_REVENUE Exported!")
# Out:
# DAILY_REVENUE Exported!

# %%
revenue_by_country_df.write \
    .format("snowflake") \
    .options(**snowflakeOptions) \
    .option("dbtable", "REVENUE_BY_COUNTRY") \
    .mode("overwrite") \
    .save()

print("REVENUE_BY_COUNTRY Exported!")
# Out:
# REVENUE_BY_COUNTRY Exported!

# %%
print("Top Customers Count:", top_customers_df.count())

print("Daily Revenue Count:", daily_revenue_df.count())

print("Revenue By Country Count:", revenue_by_country_df.count())
# Out:
# Top Customers Count: 9370
# Daily Revenue Count: 366
# Revenue By Country Count: 10

# %%
print("SNOWFLAKE EXPORT COMPLETED SUCCESSFULLY!")
# Out:
# SNOWFLAKE EXPORT COMPLETED SUCCESSFULLY!
